# %% [markdown]
# # P1 Preparación de datos

# %% [markdown]
# Importación de librerías y base de datos

# %%
import pandas as ps
import numpy as ny

# %%
df=ps.read_csv("players_20.csv")

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %% [markdown]
# Visualización de datos

# %%
df.shape
# Out:
# (18278, 104)

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#    height_cm  weight_kg nationality          club  ...   lwb   ldm   cdm  \
# 0        170         72   Argentina  FC Barcelona  ...  68+2  66+2  66+2
# 1        187         83    Portugal      Juventus  ...  65+3  61+3  61+3
#
#     rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  65+3  61+3  53+3  53+3  53+3  61+3
#
# [2 rows x 104 columns]

# %%
df.tail(2)
# Out:
#        sofifa_id                                         player_url  \
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#          short_name long_name  age         dob  height_cm  weight_kg  \
# 18276  Wang Haijian       汪海健   18  2000-08-02        185         74
# 18277    Pan Ximing       潘喜明   26  1993-01-11        182         78
#
#       nationality                           club  ...   lwb   ldm   cdm   rdm  \
# 18276    China PR  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2
# 18277    China PR         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2
#
#         rwb    lb   lcb    cb   rcb    rb
# 18276  48+2  48+2  49+2  49+2  49+2  48+2
# 18277  48+2  48+2  50+2  50+2  50+2  48+2
#
# [2 rows x 104 columns]

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=104)

# %%
df.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 104, dtype: object

# %% [markdown]
# *Hay cosas que no sirven como el URL por lo que eliminarlos sería la mejor opción

# %%
limpieza1=df.drop(['player_url', 'sofifa_id'], axis=1)

# %%
limpieza1
# Out:
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# 2              Neymar Jr        Neymar da Silva Santos Junior   27
# 3               J. Oblak                            Jan Oblak   26
# 4              E. Hazard                          Eden Hazard   28
# ...                  ...                                  ...  ...
# 18273         Shao Shuai                                   邵帅   22
# 18274       Xiao Mingjie                         Mingjie Xiao   22
# 18275          Zhang Wei                                   张威   19
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# ...

# %% [markdown]
# Cambiamos el nombre de una columna importante y la guardamos en la tabla que usaremos para hacer las clases

# %%
Tabla=limpieza1.rename(columns = {"team_position":"posicion"})

# %%
Tabla.posicion.unique()
# Out:
# array(['RW', 'LW', 'CAM', 'GK', 'RCM', 'LCB', 'ST', 'CDM', 'LDM', 'RM',
#        'RCB', 'LCM', 'LM', 'CF', 'SUB', 'LB', 'LS', 'RB', 'RDM', 'RES',
#        'RAM', 'RS', 'RF', 'CM', 'CB', 'LF', 'LAM', nan, 'RWB', 'LWB'],
#       dtype=object)

# %% [markdown]
# Se crea un csv donde solo contenga a los porteros

# %%
porteria=Tabla[Tabla['posicion']=='GK'] 
porteria.to_csv('Porteros.csv', index=False)

# %% [markdown]
# Se crea un csv donde solo tenga a mediocampistas

# %%
CAM=Tabla[Tabla['posicion']=='CAM']
CAM.to_csv('Mediocampistas.csv', index=False)

# %%
RCM=Tabla[Tabla['posicion']=='RCM']
RCM.to_csv('Mediocampistas.csv', mode='a', header=False) #https://stackoverrun.com/es/q/4773984

# %%
CDM=Tabla[Tabla['posicion']=='CDM']
CDM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
LDM=Tabla[Tabla['posicion']=='LDM']
LDM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
RM=Tabla[Tabla['posicion']=='RM']
RM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
LCM=Tabla[Tabla['posicion']=='LCM']
LCM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
LM=Tabla[Tabla['posicion']=='LM']
LM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
RDM=Tabla[Tabla['posicion']=='RDM']
RDM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
RAM=Tabla[Tabla['posicion']=='RAM']
RAM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %%
LAM=Tabla[Tabla['posicion']=='LAM']
LAM.to_csv('Mediocampistas.csv', mode='a', header=False)

# %% [markdown]
# Se crea un csv donde solo tenga defensas

# %%
LCB=Tabla[Tabla['posicion']=='LCB']
LCB.to_csv("Defensas.csv", index=False)

# %%
RCB=Tabla[Tabla['posicion']=='RCB']
RCB.to_csv('Defensas.csv', mode='a', header=False)

# %%
SUB=Tabla[Tabla['posicion']=='SUB']
SUB.to_csv('Defensas.csv', mode='a', header=False)

# %%
LB=Tabla[Tabla['posicion']=='LB']
LB.to_csv('Defensas.csv', mode='a', header=False)

# %%
RB=df[df['team_position']=='RB']
RB.to_csv('Defensas.csv', mode='a', header=False)

# %%
CB=Tabla[Tabla['posicion']=='CB']
CB.to_csv('Defensas.csv', mode='a', header=False)

# %%
RWB=Tabla[Tabla['posicion']=='RWB']
RWB.to_csv('Defensas.csv', mode='a', header=False)

# %%
LWB=Tabla[Tabla['posicion']=='LWB']
LWB.to_csv('Defensas.csv', mode='a', header=False)

# %% [markdown]
# Se crea un csv para delanteros

# %%
ST=Tabla[Tabla['posicion']=='ST']
ST.to_csv('Delanteros.csv', index=False)

# %%
CF=Tabla[Tabla['posicion']=='CF']
CF.to_csv('Delanteros.csv', mode='a', header=False)

# %%
LS=Tabla[Tabla['posicion']=='LS']
LS.to_csv('Delanteros.csv', mode='a', header=False)

# %%
RES=Tabla[Tabla['posicion']=='RES']
RES.to_csv('Delanteros.csv', mode='a', header=False)

# %%
RS=Tabla[Tabla['posicion']=='RS']
RS.to_csv('Delanteros.csv', mode='a', header=False)

# %%
RW=Tabla[Tabla['posicion']=='RW']
RW.to_csv('Delanteros.csv', mode='a', header=False)

# %%
LW=Tabla[Tabla['posicion']=='LW']
LW.to_csv('Delanteros.csv', mode='a', header=False)

# %%
RF=Tabla[Tabla['posicion']=='RF']
RF.to_csv('Delanteros.csv', mode='a', header=False)

# %%
LF=Tabla[Tabla['posicion']=='LF']
LF.to_csv('Delanteros.csv', mode='a', header=False)

# %%
porteros = ps.read_csv("Porteros.csv")

# %%
defensas = ps.read_csv("Defensas.csv")

# %%
mediocampistas = ps.read_csv("Mediocampistas.csv")

# %%
delanteros = ps.read_csv("Delanteros.csv")

# %% [markdown]
# # Preguntas de interés:
# * El separar los datos nos ayuda ha hacer más eficeinte el poder visualizarlos y trabajar con ellos
# * Detectar valores nulos que puden mover nuestra muestra de una manera que no queramos, o para optimizar nuestros procesos y memoria
